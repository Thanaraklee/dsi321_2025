# %%
import pandas as pd
from config.path_config import lakefs_s3_path, storage_options

# %%
data = pd.read_parquet(
    lakefs_s3_path,
    storage_options=storage_options,
    engine='pyarrow',
)

data.head()
# Out:
#          username                                          tweetText  \
# 0  @PrakhxngThiti  ขออนุญาตสอบถามค่ะ เกี่ยวกับรอบ 2 มธ
# ว่าเค้าเช็...
# 1   @Anuyada_2548  หนูเป็นเด็ก68ค่ะ ฐานะทางบ้านไม่ค่อยดี ตอนนี้กำ...
# 2         @cctw_4  พี่ๆคะ หนูเป็นเด็ก68 มาขอกำลังใจค่ะ ปีนี้หนูยื...
# 3   @IMYOURNIGHT1  มีพี่ ๆ คนไหน ลงความสัมพันธ์ระหว่างประเทศ หนูจ...
# 4        @yxnxpha  สอบถามพี่ ๆ คั้บบ
# นิติมธ.รอบ2นี้การแข่งขันสูง...
#
#           postTimeRaw                 scrapeTime                  tag  \
# 0 2025-01-13 15:56:22 2025-05-08 14:44:34.211177  ธรรมศาสตร์ช้างเผือก
# 1 2025-01-13 09:50:43 2025-05-08 14:44:34.211177  ธรรมศาสตร์ช้างเผือก
# 2 2025-01-13 09:41:49 2025-05-08 14:44:34.211177  ธรรมศาสตร์ช้างเผือก
# 3 2025-01-13 00:28:33 2025-05-08 14:44:34.211177  ธรรมศาสตร์ช้างเผือก
# 4 2025-01-14 16:04:43 2025-05-08 14:44:34.211177  ธรรมศาสตร์ช้างเผือก
#
#              postTime  year month day
# 0 2025-01-13 15:56:22  2025     1  13
# 1 2025-01-13 09:50:43  2025     1  13
# 2 2025-01-13 09:41:49  2025     1  13
# 3 2025-01-13 00:28:33  2025     1  13
# 4 2025-01-14 16:04:43  2025     1  14
